# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Practica 1: Análisis Exploratorio
#
# ### Base de Datos: Riesgo para la Salud Materna
#
# ##### Realizado por: Ixchel Dafne Avendaño Pacheco
#
# ##### Matricula: 23265456

# %% [markdown]
# <img src=data:image/png;base64,... >

# %% [markdown]
# Iniciamos cargando la base de datos

# %%
df = pd.read_csv(r'Maternal.csv')

# %% [markdown]
# Imprimimos la base de datos

# %%
print(df);
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %% [markdown]
# ##### Histograma.
#
#
# Obtenemos el histograma de la edad, la presión sistólica, la presión distólica, la glucosa en sangre, la temperatura corporal y el ritmo cardiaco.
#
# Utilizamos el comando figsize para hacer las gráficas más agradables a la vista en cuestión de tamaño. Además utilizamos el color #E6B0AA en hexadecimal.

# %%
df.hist(figsize= (10,10), color='#E6B0AA' );

# %% [markdown]
# ##### Presión sangínea
# En el siguiente grafico podemos observar la relación entre la presión diastólica y la presión sistólica de mujeres embarazdas. Podemos notar que la mayor concentración se encuentra en 120/80 lo que corresponde a una presión sanguinea "saludable"
#
# Observemos además que existen mujeres que presentaron hipotensión con presiones cercanas a 70/50. O mujeres que presentaron hipertensión con presiones cercanas a 160/100

# %%
sns.jointplot(data=df, x="SystolicBP", y="DiastolicBP", kind='hex', color='#E6B0AA',height=15);
plt.title("Relación entre la presión sistólica y la presión diastólica");

# %% [markdown]
# ##### Edad
#
# La edad de las mujeres embarazadas es un factor importante que puede afectar tanto la salud de la madre como la del bebé. En el caso de las adolescentes embarazadas, tienen un mayor riesgo de complicaciones durante el embarazo y el parto. Por otro lado, las mujeres mayores de 35 años tienen un mayor riesgo de complicaciones durante el embarazo y el parto, como la preeclampsia, la diabetes gestacional y el parto prematuro. Además, tienen un mayor riesgo de tener un bebé con anomalías cromosómicas, como el síndrome de Down.
#
#
# Observemos que la mayor concentración de edad se tiene entre los 18- 25 años. Para tener una visualización clara se utiliza una gráfica de violin

# %%
x=np.arange(len(df['Age']))
sns.violinplot(x=df["Age"], color='#E6B0AA');
plt.title("Edad de las participantes");

# %% [markdown]
# ##### Relación Presión Sanguínea
#
#
#
# La presión arterial se mide en dos valores: la presión sistólica y la presión diastólica. La presión sistólica es la presión en las arterias cuando el corazón late, mientras que la presión diastólica es la presión en las arterias cuando el corazón está en reposo entre latidos. En mujeres embarazadas, la presión arterial normal es de alrededor de 120/80 mmHg. La hipertensión gestacional se diagnostica cuando la presión arterial sistólica es mayor o igual a 140 mmHg y/o la presión arterial diastólica es mayor o igual a 90 mmHg después de la semana 20 de embarazo. La presión arterial alta en el embarazo puede causar complicaciones como la preeclampsia y el nacimiento prematuro

# %%
sns.histplot(df, x="SystolicBP",y="DiastolicBP", hue="HeartRate", element="step", palette="flare",) .set_title("Relación entre la Presión Sistólica, diastólica y el ritmo cardiaco");

# %% [markdown]
# ##### Relación entre la Temperatura Corporal y la Glucosa en Sangre
# A continuación, se presenta una gráfica donde podemos apreciar la relación entre la temperatura corporal y la concentración de glucosa en sangre.
#
# La relación entre la temperatura y los niveles de glucosa en sangre en mujeres embarazadas no está completamente comprendida por los investigadores. En mujeres con diabetes gestacional, la placenta produce una hormona que hace que el cuerpo sea menos sensible a la insulina, lo que aumenta la necesidad de insulina durante el embarazo

# %%
sns.relplot(data=df, x=x, y="BodyTemp", hue="BS");
plt.xlabel("Total de mujeres embarazadas");
plt.title("Relación entre la Temperatura Corporal y la Glucosa en Sangre");

# %% [markdown]
# ##### Relación entre la Presión Sistólica, Presión Diastólica y Glucosa en Sangre
#
# A continuación, se presenta una gráfica donde podemos apreciar la relación entre la Presión Sistólica, Presión Diastólica y Glucosa en Sangre.
#
# se sabe que la hipertensión gestacional y la diabetes gestacional son dos condiciones que pueden afectar tanto la presión arterial como los niveles de glucosa en sangre en mujeres embarazadas.

# %%
sns.catplot(
    data=df, x='SystolicBP', y="DiastolicBP", hue="BS",
    kind="violin", bw=.25, cut=0 , height=7);
plt.title("Relación entre la Presión Sistólica, Presión Diastólica y Glucosa en Sangre");

# %% [markdown]
# #### Matplotlib

# %% [markdown]
# ##### Relación entre la Edad y la Glucosa en Sangre
# A continuación, se presenta una gráfica donde podemos apreciar la relación entre la Edad y la Glucosa en Sangre. Notemos que como se mostro en la gráfica de edad, tenemos una mayor concentración de población en el rango entre 18-25, por lo cual podemos observar un mayor numero de concentración.

# %%
fig, ax = plt.subplots()
ax.scatter(df['Age'],df['BS'], c='pink', edgecolors='black')
plt.title("Grafica relación entre la Edad y la Glucosa en Sangre")
plt.xlabel("Edad")
plt.ylabel("Glucosa en sangre");

# %% [markdown]
# ##### Ritmo Cardiaco
#
# A continuación, se presenta una gráfica donde podemos apreciar el Ritmo cardiaco de las mujeres embarazadas. Podemos observar de forma clara que el ritmo ha aumentando entre 15 - 20 pulsaciones más de lo que se espera para una persona promedio.

# %%
fig, ax = plt.subplots()
ax.step(x, df["HeartRate"], linewidth=2, c='pink', marker='8' );
plt.title("Grafica Ritmo Cardiaco")
plt.xlabel("Mujeres Embarazadas")
plt.ylabel("Ritmo Cardiaco");

# %% [markdown]
# ##### Relación entre la Edad y la Glucosa en Sangre
# A continuación, se presenta una gráfica donde podemos apreciar la relación entre la Edad y la Glucosa en Sangre. Notemos que como se mostro en la gráfica de edad, tenemos una mayor concentración de población en el rango entre 18-25, por lo cual podemos observar un mayor numero de concentración.

# %%
fig, ax = plt.subplots()
ax.hexbin(df['Age'], df['BS'], gridsize=15, alpha = 1, edgecolor='black', cmap='flare')
plt.title("Relación entre la Edad y la Glucosa en Sangre")
plt.xlabel("Edad")
plt.ylabel("Glucosa en sangre");

# %% [markdown]
# ##### Glucosa en sanagre
# A continuación se muestra la relación de la Glucosa en sangre de las mujeres embarazdas que cornformaron esta base de datos. Podemos observar que en la mayoría de las mujeres se presentan valores saludables de Glucosa en sangre, que corresponde a 5,6 mmol/L

# %%
fig, ax = plt.subplots()
ax.hist2d(x, df['BS'], color='black' ,cmap = 'BuPu')
plt.title("Glucosa en Sangre ")
plt.xlabel("Mujeres Embarazadas")
plt.ylabel("Glucosa en sangre");

# %% [markdown]
# #### Conclusiones
#
# El embarazo es una etapa de la vida de la mujer que requiere cuidados especiales, ya que existen diversos factores que pueden generar riesgos tanto para la madre como para el feto. Entre los factores de riesgo más importantes se encuentran la presión arterial alta, el ritmo cardiaco, la concentración de glucosa en sangre, la temperatura y la edad. La presión arterial alta no controlada puede provocar daño en los riñones de la madre y aumentar el riesgo de tener preeclampsia o un bebé con peso bajo. Además, las mujeres con problemas cardíacos congénitos tienen un mayor riesgo de tener un bebé con algún tipo de defecto cardíaco. Los niveles altos de glucosa en sangre pueden ser perjudiciales para el bebé durante las primeras semanas de embarazo, incluso antes de saber que está embarazada. La hipertensión en el embarazo es otra complicación que puede tener graves consecuencias tanto para la madre como para el feto. Por lo tanto, es importante que las mujeres embarazadas se realicen controles periódicos y sigan las recomendaciones de su médico para prevenir y controlar estos riesgos.
